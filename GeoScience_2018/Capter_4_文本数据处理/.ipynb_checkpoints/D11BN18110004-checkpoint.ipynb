# %%
import pandas as pd
import matplotlib.pylab as plt
import numpy as np
# %matplotlib inline

# %% [markdown]
# ### Read from csv file
# > pandas.read_csv(filepath_or_buffer, sep=', ', delimiter=None, header='infer', names=None, index_col=None, usecols=None, squeeze=False, prefix=None, mangle_dupe_cols=True, dtype=None, engine=None, converters=None, true_values=None, false_values=None, skipinitialspace=False, skiprows=None, skipfooter=None, nrows=None, na_values=None, keep_default_na=True, na_filter=True, verbose=False, skip_blank_lines=True, parse_dates=False, infer_datetime_format=False, keep_date_col=False, date_parser=None, dayfirst=False, iterator=False, chunksize=None, compression='infer', thousands=None, decimal='.', lineterminator=None, quotechar='"', quoting=0, escapechar=None, comment=None, encoding=None, dialect=None, tupleize_cols=False, error_bad_lines=True, warn_bad_lines=True, skip_footer=0, doublequote=True, delim_whitespace=False, as_recarray=False, compact_ints=False, use_unsigned=False, low_memory=True, buffer_lines=None, memory_map=False, float_precision=None)

# %%
filename = 'C:/Data/D11BN18110004/T_DA_DXG_JS2003.csv'
dataset = pd.read_csv(filename,index_col='DATA_DATE')
dataset
# Out:
#                       ID  PRE
# DATA_DATE
# 2003/1/1 00:00:00      1  0.0
# 2003/1/2 00:00:00      2  0.0
# 2003/1/3 00:00:00      3  0.0
# 2003/1/4 00:00:00      4  0.0
# 2003/1/5 00:00:00      5  0.0
# 2003/1/6 00:00:00      6  0.0
# 2003/1/7 00:00:00      7  0.0
# 2003/1/8 00:00:00      8  0.0
# 2003/1/9 00:00:00      9  0.3
# 2003/1/10 00:00:00    10  0.1
# 2003/1/11 00:00:00    11  0.0
# 2003/1/12 00:00:00    12  0.0
# 2003/1/13 00:00:00    13  0.0
# 2003/1/14 00:00:00    14  0.0
# 2003/1/15 00:00:00    15  0.0
# 2003/1/16 00:00:00    16  0.0
# 2003/1/17 00:00:00    17  0.0
# 2003/1/18 00:00:00    18  0.0
# 2003/1/19 00:00:00    19  0.0
# 2003/1/20 00:00:00    20  0.0
# 2003/1/21 00:00:00    21  0.0
# 2003/1/22 00:00:00    22  0.0
# 2003/1/23 00:00:00    23  0.3
# 2003/1/24 00:00:00    24  0.0
# 2003/1/25 00:00:00    25  0.0
# 2003/1/26 00:00:00    26  0.0
# 2003/1/27 00:00:00    27  0.0
# 2003/1/28 00:00:00    28  0.0
# 2003/1/29 00:00:00    29  0.0
# ...

# %%
### 将Data_Date转换为日期类型

# %%
dataset = pd.read_csv(filename,index_col='date',parse_dates={'date':['DATA_DATE']})
dataset
# Out:
#              ID  PRE
# date
# 2003-01-01    1  0.0
# 2003-01-02    2  0.0
# 2003-01-03    3  0.0
# 2003-01-04    4  0.0
# 2003-01-05    5  0.0
# 2003-01-06    6  0.0
# 2003-01-07    7  0.0
# 2003-01-08    8  0.0
# 2003-01-09    9  0.3
# 2003-01-10   10  0.1
# 2003-01-11   11  0.0
# 2003-01-12   12  0.0
# 2003-01-13   13  0.0
# 2003-01-14   14  0.0
# 2003-01-15   15  0.0
# 2003-01-16   16  0.0
# 2003-01-17   17  0.0
# 2003-01-18   18  0.0
# 2003-01-19   19  0.0
# 2003-01-20   20  0.0
# 2003-01-21   21  0.0
# 2003-01-22   22  0.0
# 2003-01-23   23  0.3
# 2003-01-24   24  0.0
# 2003-01-25   25  0.0
# 2003-01-26   26  0.0
# 2003-01-27   27  0.0
# 2003-01-28   28  0.0
# 2003-01-29   29  0.0
# 2003-01-30   30  0.0
# ...         ...  ...
# 2003-12-02  336  0.0
# 2003-12-03  337  0.0
# 2003-12-04  338  0.0
# 2003-12-05  339  0.0
# 2003-12-06  340  0.0
# 2003-12-07  341  0.0
# 2003-12-08  342  0.0
# 2003-12-09  343  0.0
# 2003-12-10  344  0.0
# 2003-12-11  345  0.0
# 2003-12-12  346  0.0
# ...

# %%
figure = plt.figure(figsize=(20,8))
plt.plot(dataset.index,dataset['PRE'].values)
plt.xlabel('Date')
plt.ylabel('Precipitation/mm')

# %%
##2004
filename_2004 = 'C:/Data/D11BN18110004/T_DA_DXG_JS2004.csv'
column_names=['ID','Timestamp','Precipation']
ds_2004 = pd.read_csv(filename_2004,parse_dates={'Date':['Timestamp']},index_col='Date',\
                      names=column_names,header=1)
ds_2004

filename_2005 = 'C:/Data/D11BN18110004/T_DA_DXG_JS2005.csv'
column_names=['ID','Timestamp','Precipation']
ds_2005 = pd.read_csv(filename_2005,parse_dates={'Date':['Timestamp']},index_col='Date',names=column_names,header=1)
# Out:
#              ID  Precipation
# Date
# 2004-01-02    2          0.0
# 2004-01-03    3          0.0
# 2004-01-04    4          0.0
# 2004-01-05    5          0.0
# 2004-01-06    6          0.0
# 2004-01-07    7          0.0
# 2004-01-08    8          0.0
# 2004-01-09    9          0.0
# 2004-01-10   10          0.0
# 2004-01-11   11          0.0
# 2004-01-12   12          0.3
# 2004-01-13   13          0.3
# 2004-01-14   14          0.1
# 2004-01-15   15          0.0
# 2004-01-16   16          0.0
# 2004-01-17   17          0.0
# 2004-01-18   18          1.2
# 2004-01-19   19          3.2
# 2004-01-20   20          0.0
# 2004-01-21   21          0.0
# 2004-01-22   22          0.0
# 2004-01-23   23          0.0
# 2004-01-24   24          0.0
# 2004-01-25   25          0.0
# 2004-01-26   26          0.0
# 2004-01-27   27          0.0
# 2004-01-28   28          0.0
# 2004-01-29   29          0.0
# 2004-01-30   30          0.0
# 2004-01-31   31          0.1
# ...         ...          ...
# ...

# %% [markdown]
# * merge
# * join
# * concat
# > pandas.concat(objs, axis=0, join='outer', join_axes=None, ignore_index=False, keys=None, levels=None, names=None, verify_integrity=False, copy=True)
